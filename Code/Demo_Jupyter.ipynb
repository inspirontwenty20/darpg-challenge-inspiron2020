# %%
import warnings
warnings.simplefilter('ignore')

import helper_import_path

import model_executor_for_demo as mba
import Demo_Jupyter_helper as djh

# %%
## Invoke Model Builder
warnings.simplefilter('ignore')


model,encoder_array = mba.driver_code_get_model()
# Out:
# Train Data, number of rows before drop na (18865, 6)
# Train Data, number of rows After drop na (18861, 6)
# (18865, 6)
# ...

# %%
subject_content = 'In this case the return of income under section ***(*) of the Act was filed by us on **.**.**** declaring an income of Rs.********. The tax of Rs.******** was adjusted against the MAT credit entitlement of Rs.********. The entire TDS of Rs. ******** was claimed as refund. The said return was processed under section ***(*) of the Act on **.**.**** and a refund of Rs.******** was  determined. In the said intimation under section ***(*) of the Act it was mentioned that the said refund of Rs.******** was refunded vide refund sequence no.**********. However the said refund has not yet been received by us.  we therefore request you to kindly look into the matter and issue the refund at the earliest.'
country_name = 'India'
state_name = 'West Bengal'


test_df,pred,pred_labels = djh.get_prediction_on_input_data(model,encoder_array,country_name, state_name, 
                                           subject_content)

print(".............................................................")
print("Predicted class of department",pred)
print("Predicted Name of department",pred_labels)
# Out:
# .............................................................
# Predicted class of department [0]
# Predicted Name of department ['Central Board of Direct Taxes (Income Tax)']

# %%
subject_content = 'The hospitals are not accepting ayushman card and sending pateints away.'
country_name = 'India'
state_name = 'Uttar Pradesh'


test_df,pred, pred_labels = djh.get_prediction_on_input_data(model,encoder_array,country_name, state_name, 
                                           subject_content)

print('.......................................................')
print("Predicted class of department",pred)
print("Predicted Name of department",pred_labels)
# Out:
# .......................................................
# Predicted class of department [6]
# Predicted Name of department ['Department of Financial Services (Banking Division)']
